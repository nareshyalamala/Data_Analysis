# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/Movie_collection_Target.csv")

# %%
df
# Out:
#      Collection
# 0      2.266667
# 1      2.106667
# 2      2.980000
# 3      2.893333
# 4      3.080000
# ..          ...
# 501    2.160000
# 502    2.040000
# 503    2.260000
# 504    2.133333
# 505    1.933333
#
# [506 rows x 1 columns]

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/Movie_collection_Independent.csv")

# %%
df2
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
y=df['Collection']

# %%
X= df2

# %%
X_train,X_test=X[:400],X[400:]
y_train,y_test=y[:400],y[400:]

# %%
X_train
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 395          194.3350               91.20               0.307  35946.405
# 396          137.4410               91.20               0.307  35579.775
# 397          173.4404               91.20               0.307  31924.585
# 398          787.0360               91.20               0.307  30291.415
# 399          218.3310               91.20               0.307  32507.860
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
X_test
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 400          520.9220               91.20               0.307  33257.785
# 401          304.7240               91.20               0.307  35235.365
# 402          211.9142               91.20               0.307  35574.220
# 403          516.0340               91.20               0.307  29713.695
# 404          850.5840               91.20               0.307  30724.705
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.head())
# Out:
# array([1.60919383, 2.05291894, 1.93026991, 1.40613111, 1.33603292])

# %%
np.array(y_test)
# Out:
# array([1.04      , 1.14666667, 1.47333333, 1.22      , 1.23333333,
#        1.        , 1.46      , 2.52666667, 1.81333333, 2.5       ,
#        1.66666667, 1.81333333, 1.86      , 1.75333333, 1.13333333,
#        1.14666667, 1.16666667, 1.36      , 1.25333333, 1.22666667,
#        1.78      , 1.61333333, 2.05333333, 1.56      , 1.44666667,
#        1.22      , 1.34666667, 1.39333333, 1.4       , 1.3       ,
#        1.63333333, 1.60666667, 1.74      , 1.62      , 1.44666667,
#        1.56      , 1.30666667, 1.21333333, 1.22666667, 1.52      ,
#        1.36666667, 1.80666667, 1.65333333, 1.69333333, 1.38666667,
#        1.45333333, 1.66      , 1.50666667, 1.60666667, 1.53333333,
#        1.56      , 1.68      , 1.74      , 1.85333333, 1.62666667,
#        1.60666667, 1.51333333, 1.56666667, 1.66      , 2.        ,
#        1.76      , 1.84666667, 1.96666667, 2.01333333, 2.09333333,
#        1.99333333, 1.93333333, 1.94      , 1.94      , 2.00666667,
# ...

# %%
lr.score(X_test,y_test)
# Out:
# -0.332658859107547

# %%
#random forest_regression_model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rd=RandomForestRegressor()

# %%
rd.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rd.predict(X_test)
# Out:
# array([1.34173333, 1.42626667, 1.528     , 1.48273333, 1.26966667,
#        1.38233333, 1.5244    , 1.8322    , 1.39953333, 2.6214    ,
#        2.9234    , 1.54933333, 1.29326667, 1.38493333, 1.35866667,
#        1.42146667, 1.67773333, 1.36953333, 1.41193333, 1.9446    ,
#        1.6528    , 1.6912    , 2.06313333, 1.6772    , 1.68446667,
#        1.5722    , 1.6714    , 1.74213333, 1.65906667, 1.53586667,
#        1.71586667, 2.37333333, 2.16706667, 1.9066    , 1.709     ,
#        1.57633333, 1.66886667, 1.469     , 1.4294    , 1.54533333,
#        1.509     , 1.65486667, 1.74413333, 1.58353333, 1.50253333,
#        1.5774    , 1.787     , 1.63206667, 1.70246667, 1.71833333,
#        1.9534    , 1.78246667, 1.9188    , 2.3838    , 1.83726667,
#        1.90593333, 1.7746    , 1.801     , 1.77173333, 1.88046667,
#        2.02326667, 1.90826667, 2.12846667, 2.24133333, 2.168     ,
#        1.93093333, 1.79333333, 1.71733333, 1.6276    , 1.77633333,
# ...

# %%
rd.score(X_test,y_test)
# Out:
# 0.27830312304819715
